# %% [markdown]
# # Final Project
#
# ### Calvin Warner, DK Yuan

# %% [markdown]
# ## Progress Report 2
#
#
# The research question for our project is can we use statistical learning methods to accurately predict if a mushroom is edible or poisonous.
#
# As a primer for the paper we did some simple data cleaning and organizing to prepare for further analysis. This report is a collection of preliminary analyses.

# %%
import csv
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn import metrics
from sklearn.model_selection import train_test_split as tts
import math

fn = "mushrooms.csv"

df = pd.read_csv(fn)

df.head(6)
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
#
#   gill-spacing gill-size gill-color   ...   stalk-surface-below-ring  \
# 0            c         n          k   ...                          s
# 1            c         b          k   ...                          s
# 2            c         b          n   ...                          s
# 3            c         n          n   ...                          s
# 4            w         b          k   ...                          s
# 5            c         b          n   ...                          s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# 1                      w                      w         p          w
# 2                      w                      w         p          w
# 3                      w                      w         p          w
# 4                      w                      w         p          w
# 5                      w                      w         p          w
#
#   ring-number ring-type spore-print-color population habitat
# 0           o         p                 k          s       u
# 1           o         p                 n          n       g
# 2           o         p                 n          n       m
# 3           o         p                 k          s       u
# 4           o         e                 n          a       g
# 5           o         p                 k          n       g
#
# [6 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %% [markdown]
# There appears to be no null values, but a quick look at the documentation the data is marked for missingness with a `?`. So we must go through the data to get rid of all the question marks, so that does not become a class.

# %%
df = df.replace('?', np.NaN)

# %%
df['stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r', nan], dtype=object)

# %% [markdown]
# **Ok**, now lets delete all the rows that contain a null value.

# %%
df = df.dropna()

# %% [markdown]
# Lets check to make sure that deleted rows.

# %%
df['stalk-root'].unique()
# Out:
# array(['e', 'c', 'b', 'r'], dtype=object)

# %% [markdown]
# Looks good! Now we can encode the labels to be numeric so we can run logistic regression.

# %%
le=LabelEncoder()
for col in df.columns:
    df[col] = le.fit_transform(df[col])
 
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          7        1     0                1
# 2      0          0            2          6        1     3                1
# 3      1          5            3          6        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color   ...     stalk-surface-below-ring  \
# 0             0          1           2   ...                            2
# 1             0          0           2   ...                            2
# 2             0          0           3   ...                            2
# 3             0          1           3   ...                            2
# 4             1          0           2   ...                            2
#
#    stalk-color-above-ring  stalk-color-below-ring  veil-type  veil-color  \
# 0                       5                       5          0           0
# 1                       5                       5          0           0
# 2                       5                       5          0           0
# 3                       5                       5          0           0
# 4                       5                       5          0           0
#
#    ring-number  ring-type  spore-print-color  population  habitat
# 0            1          3                  1           3        5
# 1            1          3                  2           2        1
# 2            1          3                  2           2        3
# 3            1          3                  1           3        5
# 4            1          0                  2           0        1
#
# [5 rows x 23 columns]

# %% [markdown]
# Seperating the data into Y and X for analysis.

# %%
x = df.iloc[:,1:23]
y = df.iloc[:, 0]
x.head()
y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int64

# %%
x.describe()
# Out:
#          cap-shape  cap-surface    cap-color      bruises         odor  \
# count  5644.000000  5644.000000  5644.000000  5644.000000  5644.000000
# mean      3.420269     1.627215     4.272856     0.564139     3.564848
# std       1.659641     1.336497     1.838018     0.495913     1.765806
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     3.000000     0.000000     2.000000
# 50%       5.000000     2.000000     4.000000     1.000000     5.000000
# 75%       5.000000     3.000000     6.000000     1.000000     5.000000
# max       5.000000     3.000000     7.000000     1.000000     6.000000
#
#        gill-attachment  gill-spacing    gill-size   gill-color  stalk-shape  \
# count      5644.000000   5644.000000  5644.000000  5644.000000  5644.000000
# mean          0.996811      0.181432     0.124734     3.536853     0.510276
# std           0.056388      0.385410     0.330447     2.281428     0.499939
# min           0.000000      0.000000     0.000000     0.000000     0.000000
# 25%           1.000000      0.000000     0.000000     2.000000     0.000000
# 50%           1.000000      0.000000     0.000000     4.000000     1.000000
# 75%           1.000000      0.000000     0.000000     6.000000     1.000000
# max           1.000000      1.000000     1.000000     8.000000     1.000000
#
#           ...       stalk-surface-below-ring  stalk-color-above-ring  \
# count     ...                    5644.000000             5644.000000
# mean      ...                       1.619419                3.949681
# std       ...                       0.721620                1.526058
# min       ...                       0.000000                0.000000
# 25%       ...                       1.000000                3.000000
# 50%       ...                       2.000000                5.000000
# 75%       ...                       2.000000                5.000000
# max       ...                       3.000000                6.000000
#
#        stalk-color-below-ring  veil-type   veil-color  ring-number  \
# count             5644.000000     5644.0  5644.000000  5644.000000
# mean                 3.932672        0.0     0.001417     1.014883
# std                  1.525402        0.0     0.037625     0.165600
# min                  0.000000        0.0     0.000000     0.000000
# 25%                  3.000000        0.0     0.000000     1.000000
# 50%                  5.000000        0.0     0.000000     1.000000
# 75%                  5.000000        0.0     0.000000     1.000000
# max                  6.000000        0.0     1.000000     2.000000
#
#          ring-type  spore-print-color   population      habitat
# count  5644.000000        5644.000000  5644.000000  5644.000000
# mean      2.096386           1.215450     3.712970     1.236003
# std       1.192716           1.059125     1.328741     1.597981
# min       0.000000           0.000000     0.000000     0.000000
# 25%       1.000000           0.000000     3.000000     0.000000
# 50%       3.000000           1.000000     4.000000     1.000000
# 75%       3.000000           2.000000     5.000000     1.000000
# max       3.000000           5.000000     5.000000     5.000000
#
# [8 rows x 22 columns]

# %% [markdown]
# Lets take a look at the correlations between the variables.

# %%
corr = df.corr()
corr.head(3)
# Out:
#                 class  cap-shape  cap-surface  cap-color   bruises      odor  \
# class        1.000000   0.053155     0.046859   0.150741 -0.435562 -0.455566
# cap-shape    0.053155   1.000000    -0.068688  -0.056421 -0.097782  0.000011
# cap-surface  0.046859  -0.068688     1.000000   0.093355  0.228590 -0.108697
#
#              gill-attachment  gill-spacing  gill-size  gill-color    ...     \
# class              -0.071945     -0.264160   0.215289   -0.318339    ...
# cap-shape           0.002963      0.051432   0.103443   -0.006431    ...
# cap-surface        -0.058104     -0.204448  -0.042356    0.073668    ...
#
#              stalk-surface-below-ring  stalk-color-above-ring  \
# class                       -0.363604               -0.317244
# cap-shape                   -0.029780               -0.030272
# cap-surface                  0.162293                0.045018
#
#              stalk-color-below-ring  veil-type  veil-color  ring-number  \
# class                     -0.308613        NaN    0.047921     0.008615
# cap-shape                 -0.029700        NaN   -0.043596    -0.118191
# cap-surface                0.046099        NaN    0.038702     0.044289
#
#              ring-type  spore-print-color  population   habitat
# class        -0.215200          -0.507034    0.203882  0.297412
# cap-shape    -0.029420          -0.062007    0.048283 -0.057451
# cap-surface   0.190188           0.054747   -0.000390  0.106918
#
# [3 rows x 23 columns]

# %% [markdown]
# The number of observations in each class.

# %%
print(df.groupby('class').size())
# Out:
# class
# 0    3488
# 1    2156
# dtype: int64

# %% [markdown]
# Split the data into training and test sets.

# %%
xTrain, xTest, yTrain, yTest = tts(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# Create a Logistical Regression model using all the data.

# %%
modelLr = LogisticRegression()

lRegModel = modelLr.fit(xTrain,yTrain)

# %%
yProb = modelLr.predict_proba(xTest)[:,1] ## Positive class prediction probabilities

yPred = np.where(yProb > 0.5, 1, 0) # This will make the probabilities into class predictions

# %% [markdown]
# Confusion Matrix for predictions.

# %%
confusionMatrix = metrics.confusion_matrix(yTest,yPred)
confusionMatrix
# Out:
# array([[703,   6],
#        [ 34, 386]])
